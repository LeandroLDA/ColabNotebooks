# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroLDA/ColabNotebooks/blob/main/ML_para_mini_indice_Leandro_LDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODELO DE MACHINE LEARNING BASEADO EM INDICADORES PARA MINI ÍNDICES.
#
# ---
# alias: modelo ML para mini índices
# created: 13/01/2025
# ---
#
# ## RESUMO
#
# O objetico deste modelo é aplicar o aprendizado de máquina em análise gráfica de açoes. Diferentemente de outros modelos analisados este modelo introduz outros fatores que são comumente são avaliados por analistas na tomada de decisão, como por exemplo: volatilidade, médias móveis, médias estocásticas e volume financeiro.
#
# **Regras de negócio**
#  - Volatiliade
#  - Aceleração do preço
#  - Médias móveis
#   - Curtas
#   - Longas
#  - Análise estocástica
#  - Força relativa
#  - Volume financeiro (saldo)
#
#
# **Referências Úteis**
#  - [Além dos números: Estatística Inferencial como ferramenta na gestão de investimentos](https://medium.com/@ducadux/al%C3%A9m-dos-n%C3%BAmeros-estat%C3%ADstica-inferencial-como-ferramenta-na-gest%C3%A3o-de-investimentos-858b0dc2b46e)
#  -
#  -
#  -
#  -
#  -
#
#
# **Itens para estudo**
#  - Teste de tukey
#  - Teste de [levene](https://www.ufrgs.br/wiki-r/index.php?title=Teste_de_Levene&source=post_page-----858b0dc2b46e--------------------------------)
#  - Teste de [ANOVA](https://astatsa.com/OneWay_Anova_with_TukeyHSD/?source=post_page-----858b0dc2b46e--------------------------------)

# %%
import pandas as pd

# Aquisição de dados através de planilha em CSV
#from google.colab import files
#uploaded = files.upload()
#Coloque na variável csv o nome do arquivo com a extensão.

try:

  df = pd.read_csv("01-MBA-TrabalhosD01.txt")

#df.shape
except FileNotFoundError:
   print("Arquivo não encontrado!\n")
   print("Carregue o arquivo para continuar.\n")
   from google.colab import files
   uploaded = files.upload()
   print("\n", df.head())
else:
  print(df.head())

finally:
  print("\nFim do comando\n")

#df ["w"] = if ["VALOR_FIPE"]
# Out:
# Arquivo não encontrado!
#
# Carregue o arquivo para continuar.
#      <input type="file" id="files-f808164c-c592-4e99-af34-84c668f8b045" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f808164c-c592-4e99-af34-84c668f8b045">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# # Nova seção

# %%
print("hello world")
# Out:
# hello world
