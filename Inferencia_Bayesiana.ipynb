# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroLDA/ColabNotebooks/blob/main/Inferencia_Bayesiana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercicio retirado do livro de estatística de Larson Faber. "Estatística aplicada 4a ediçao" editora Pearson, ex 7 pg 149

# %% [markdown]
# Com base nas contagens anteriores, um inspetor de qualidade diz que há uma probabilidade de 0,05 de que uma peça escolhida aleatoriamente seja defeituosa.

# %%
import pymc as pm
import numpy as np
import matplotlib.pyplot as plt
import arviz as az
